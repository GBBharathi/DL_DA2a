# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
placer = pd.read_csv('//content/drive/MyDrive/AI Hackathon/placer/placer.csv')

# %%
placer
# Out:
#         Unnamed: 0                                              PCBID  \
# 0                0  9056093030018024_0048_0001_0001_20220831235024472
# 1                1  9056093030018048_0048_0001_0001_20220831235430535
# 2                2  9056093030017960_0048_0001_0001_20220831235851351
# 3                3  9056093030017968_0048_0001_0001_20220831235947179
# 4                4  9056093030017976_0048_0001_0001_20220831235553736
# ...            ...                                                ...
# 731412      159768                                   1085425020003248
# 731413      159769                                   1085425020003244
# 731414      159770                                   1085425020003244
# 731415      159771                                   1085425020003248
# 731416      159772                                   1085425020003248
#
#                  RECIPENAME  SIDE            STARTTIME              ENDTIME  \
# 0       1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:44  2022-09-01 00:00:17
# 1       1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:48  2022-09-01 00:00:18
# 2       1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:38  2022-09-01 00:00:20
# 3       1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:40  2022-09-01 00:00:31
# 4       1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:48  2022-09-01 00:00:57
# ...                     ...   ...                  ...                  ...
# 731412     1184066-01_BFUJI   1.0  2022-12-22 21:23:06  2022-12-22 21:23:12
# 731413     1184066-01_BFUJI   1.0  2022-12-22 21:23:09  2022-12-22 21:23:20
# 731414     1184066-01_BFUJI   1.0  2022-12-22 21:23:38  2022-12-22 21:23:42
# 731415     1184066-01_BFUJI   1.0  2022-12-22 21:23:42  2022-12-22 21:23:54
# 731416     1184066-01_BFUJI   1.0  2022-12-22 21:24:12  2022-12-22 21:24:17
#
#         MODULENO  NUMCOMP  NUMBLOCKS  NUMERRORS
# 0            8.0     32.0        8.0        0.0
# 1            5.0     72.0        8.0        0.0
# 2            2.0    168.0        8.0        0.0
# 3            1.0    208.0        8.0        0.0
# 4            4.0    200.0        8.0        0.0
# ...          ...      ...        ...        ...
# 731412       8.0      6.0        1.0        0.0
# 731413       9.0     12.0        1.0        0.0
# 731414      10.0      1.0        1.0        0.0
# 731415       9.0     12.0        1.0        0.0
# 731416      10.0      1.0        1.0        0.0
#
# [731417 rows x 10 columns]

# %%
placer['Furnace_ID'] = 0

# %%
placer.head()
# Out:
#    Unnamed: 0                                              PCBID  \
# 0           0  9056093030018024_0048_0001_0001_20220831235024472
# 1           1  9056093030018048_0048_0001_0001_20220831235430535
# 2           2  9056093030017960_0048_0001_0001_20220831235851351
# 3           3  9056093030017968_0048_0001_0001_20220831235947179
# 4           4  9056093030017976_0048_0001_0001_20220831235553736
#
#             RECIPENAME  SIDE            STARTTIME              ENDTIME  \
# 0  1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:44  2022-09-01 00:00:17
# 1  1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:48  2022-09-01 00:00:18
# 2  1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:38  2022-09-01 00:00:20
# 3  1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:40  2022-09-01 00:00:31
# 4  1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:48  2022-09-01 00:00:57
#
#    MODULENO  NUMCOMP  NUMBLOCKS  NUMERRORS  Furnace_ID
# 0       8.0     32.0        8.0        0.0           0
# 1       5.0     72.0        8.0        0.0           0
# 2       2.0    168.0        8.0        0.0           0
# 3       1.0    208.0        8.0        0.0           0
# 4       4.0    200.0        8.0        0.0           0

# %%
placer[0:2]
# Out:
#    Unnamed: 0                                              PCBID  \
# 0           0  9056093030018024_0048_0001_0001_20220831235024472
# 1           1  9056093030018048_0048_0001_0001_20220831235430535
#
#             RECIPENAME  SIDE            STARTTIME              ENDTIME  \
# 0  1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:44  2022-09-01 00:00:17
# 1  1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:48  2022-09-01 00:00:18
#
#    MODULENO  NUMCOMP  NUMBLOCKS  NUMERRORS  Furnace_ID
# 0       8.0     32.0        8.0        0.0           0
# 1       5.0     72.0        8.0        0.0           0

# %%
placer['ENDTIME'] = pd.to_datetime(placer['ENDTIME'],utc=True)

# %%
placer.dtypes
# Out:
# Unnamed: 0                  int64
# PCBID                      object
# RECIPENAME                 object
# SIDE                      float64
# STARTTIME                  object
# ENDTIME       datetime64[ns, UTC]
# MODULENO                  float64
# NUMCOMP                   float64
# NUMBLOCKS                 float64
# NUMERRORS                 float64
# Furnace_ID                  int64
# dtype: object

# %%
validation = pd.read_csv('/content/drive/MyDrive/AI Hackathon/validation_set.txt', sep=';', header = None)
validation.columns = ['time','energy','nitrogen_Nm3h']

# %%
validation.head()
# Out:
#                         time      energy  nitrogen_Nm3h
# 0  2022-10-11 19:50:30+00:00   9019.3995      19.440000
# 1  2022-10-11 19:50:45+00:00   6296.4840      19.428333
# 2  2022-10-11 19:51:00+00:00  15479.6640      19.585000
# 3  2022-10-11 19:51:15+00:00  11585.6500      20.127692
# 4  2022-10-11 19:51:30+00:00   6701.3010      19.685000

# %%
task_full_blanks = pd.read_csv('/content/drive/MyDrive/AI Hackathon/task_full_blanks.txt', sep=';', header = None)
task_full_blanks.columns = ['time','energy','nitrogen_Nm3h']

# %%
task_full_blanks.head()
# Out:
#                         time      energy  nitrogen_Nm3h
# 0  2022-10-20 19:09:15+00:00  14657.1150      20.976364
# 1  2022-10-20 19:09:30+00:00   7826.5360      20.900000
# 2  2022-10-20 19:09:45+00:00   8878.1625      20.586154
# 3  2022-10-20 19:10:00+00:00   1874.1160      21.177500
# 4  2022-10-20 19:10:15+00:00  11829.6765      20.780000

# %%
placer
# Out:
#         Unnamed: 0                                              PCBID  \
# 0                0  9056093030018024_0048_0001_0001_20220831235024472
# 1                1  9056093030018048_0048_0001_0001_20220831235430535
# 2                2  9056093030017960_0048_0001_0001_20220831235851351
# 3                3  9056093030017968_0048_0001_0001_20220831235947179
# 4                4  9056093030017976_0048_0001_0001_20220831235553736
# ...            ...                                                ...
# 731412      159768                                   1085425020003248
# 731413      159769                                   1085425020003244
# 731414      159770                                   1085425020003244
# 731415      159771                                   1085425020003248
# 731416      159772                                   1085425020003248
#
#                  RECIPENAME  SIDE            STARTTIME  \
# 0       1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:44
# 1       1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:48
# 2       1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:38
# 3       1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:40
# 4       1097922-00_NXT3_TL4   0.0  2022-08-31 23:59:48
# ...                     ...   ...                  ...
# 731412     1184066-01_BFUJI   1.0  2022-12-22 21:23:06
# 731413     1184066-01_BFUJI   1.0  2022-12-22 21:23:09
# 731414     1184066-01_BFUJI   1.0  2022-12-22 21:23:38
# 731415     1184066-01_BFUJI   1.0  2022-12-22 21:23:42
# 731416     1184066-01_BFUJI   1.0  2022-12-22 21:24:12
#
#                          ENDTIME  MODULENO  NUMCOMP  NUMBLOCKS  NUMERRORS  \
# 0      2022-09-01 00:00:17+00:00       8.0     32.0        8.0        0.0
# 1      2022-09-01 00:00:18+00:00       5.0     72.0        8.0        0.0
# 2      2022-09-01 00:00:20+00:00       2.0    168.0        8.0        0.0
# 3      2022-09-01 00:00:31+00:00       1.0    208.0        8.0        0.0
# 4      2022-09-01 00:00:57+00:00       4.0    200.0        8.0        0.0
# ...                          ...       ...      ...        ...        ...
# 731412 2022-12-22 21:23:12+00:00       8.0      6.0        1.0        0.0
# 731413 2022-12-22 21:23:20+00:00       9.0     12.0        1.0        0.0
# 731414 2022-12-22 21:23:42+00:00      10.0      1.0        1.0        0.0
# 731415 2022-12-22 21:23:54+00:00       9.0     12.0        1.0        0.0
# 731416 2022-12-22 21:24:17+00:00      10.0      1.0        1.0        0.0
#
#         Furnace_ID
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 731412           0
# 731413           0
# 731414           0
# 731415           0
# 731416           0
#
# [731417 rows x 11 columns]

# %%
placer = placer[260224:327769]
del placer['Unnamed: 0']
del placer['Furnace_ID']

# %%
placer
# Out:
#                    PCBID           RECIPENAME  SIDE            STARTTIME  \
# 260224  9781121080058881  1032367-03_NXT3_TL4   0.0  2022-10-11 19:52:44
# 260225  9781121080058877  1032367-03_NXT3_TL4   0.0  2022-10-11 19:52:32
# 260226  9781121080058880  1032367-03_NXT3_TL4   0.0  2022-10-11 19:52:57
# 260227  9781121080058879  1032367-03_NXT3_TL4   0.0  2022-10-11 19:52:57
# 260228  9781121080058878  1032367-03_NXT3_TL4   0.0  2022-10-11 19:53:04
# ...                  ...                  ...   ...                  ...
# 327764  9779275080026549  9054491-06_NXT3_TL4   0.0  2022-10-20 19:08:37
# 327765  9779275080026543  9054491-06_NXT3_TL4   0.0  2022-10-20 19:08:35
# 327766  9779275080026837  9054491-06_NXT3_TL4   0.0  2022-10-20 19:08:44
# 327767  9779275080026835  9054491-06_NXT3_TL4   0.0  2022-10-20 19:08:45
# 327768  9779275080026547  9054491-06_NXT3_TL4   0.0  2022-10-20 19:08:48
#
#                          ENDTIME  MODULENO  NUMCOMP  NUMBLOCKS  NUMERRORS
# 260224 2022-10-11 19:53:09+00:00       6.0     40.0        1.0        0.0
# 260225 2022-10-11 19:53:10+00:00       1.0    165.0        1.0        1.0
# 260226 2022-10-11 19:53:28+00:00       5.0     40.0        1.0        0.0
# 260227 2022-10-11 19:53:31+00:00       4.0     75.0        1.0        0.0
# 260228 2022-10-11 19:53:35+00:00       3.0    135.0        1.0        0.0
# ...                          ...       ...      ...        ...        ...
# 327764 2022-10-20 19:08:46+00:00       4.0     18.0        2.0        0.0
# 327765 2022-10-20 19:08:46+00:00       8.0     10.0        2.0        0.0
# 327766 2022-10-20 19:08:49+00:00       1.0      6.0        2.0        0.0
# 327767 2022-10-20 19:08:53+00:00       3.0     32.0        2.0        0.0
# 327768 2022-10-20 19:08:58+00:00       6.0     20.0        2.0        0.0
#
# [67545 rows x 9 columns]

# %%
placer.reset_index(inplace=True, drop=True)
placer.index = placer.index
print(placer.head())
# Out:
#               PCBID           RECIPENAME  SIDE            STARTTIME  \
# 0  9781121080058881  1032367-03_NXT3_TL4   0.0  2022-10-11 19:52:44
# 1  9781121080058877  1032367-03_NXT3_TL4   0.0  2022-10-11 19:52:32
# 2  9781121080058880  1032367-03_NXT3_TL4   0.0  2022-10-11 19:52:57
# 3  9781121080058879  1032367-03_NXT3_TL4   0.0  2022-10-11 19:52:57
# 4  9781121080058878  1032367-03_NXT3_TL4   0.0  2022-10-11 19:53:04
#
#                     ENDTIME  MODULENO  NUMCOMP  NUMBLOCKS  NUMERRORS
# 0 2022-10-11 19:53:09+00:00       6.0     40.0        1.0        0.0
# 1 2022-10-11 19:53:10+00:00       1.0    165.0        1.0        1.0
# 2 2022-10-11 19:53:28+00:00       5.0     40.0        1.0        0.0
# 3 2022-10-11 19:53:31+00:00       4.0     75.0        1.0        0.0
# 4 2022-10-11 19:53:35+00:00       3.0    135.0        1.0        0.0

# %% [markdown]
# placer

# %%
validation = validation[0:16514]
validation.head()
# Out:
#                         time      energy  nitrogen_Nm3h
# 0  2022-10-11 19:50:30+00:00   9019.3995      19.440000
# 1  2022-10-11 19:50:45+00:00   6296.4840      19.428333
# 2  2022-10-11 19:51:00+00:00  15479.6640      19.585000
# 3  2022-10-11 19:51:15+00:00  11585.6500      20.127692
# 4  2022-10-11 19:51:30+00:00   6701.3010      19.685000

# %%
validation['time'] = pd.to_datetime(validation['time'],utc=True)
# Out:
# <ipython-input-19-5afae144de4a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation['time'] = pd.to_datetime(validation['time'],utc=True)

# %%
print(placer.shape)
# Out:
# (67545, 9)

# %%
print(validation.shape)
# Out:
# (16514, 3)

# %%
placer["F_Data"]=None
for i in range(0,67545):
  for j in range(1,16514):
    if(placer.iloc[i]["ENDTIME"] < validation.iloc[j]["time"] and placer.iloc[i]["ENDTIME"] > validation.iloc[j-1]["time"]):
      placer.at[i, 'F_data'] = j
      break
# Out:
# <ipython-input-22-a3a70d56f125>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   placer["F_Data"]=None
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-a3a70d56f125> in <module>
#       2 for i in range(0,67545):
#       3   for j in range(1,16514):
# ----> 4     if(placer.iloc[i]["ENDTIME"] < validation.iloc[j]["time"] and placer.iloc[i]["ENDTIME"] > validation.iloc[j-1]["time"]):
#       5       placer.at[i, 'F_data'] = j
#       6       break
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1566             self._validate_integer(key, axis)
#    1567
# -> 1568             return self.obj._ixs(key, axis=axis)
#    1569
#    1570     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in _ixs(self, i, axis)
#    3381             # if we are a copy, mark as such
#    3382             copy = isinstance(new_values, np.ndarray) and new_values.base is None
# -> 3383             result = self._constructor_sliced(
#    3384                 new_values,
#    3385                 index=self.columns,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     431
#     432             # create/copy the manager
# --> 433             if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#     434                 if dtype is not None:
#     435                     data = data.astype(dtype=dtype, errors="ignore", copy=copy)
#
# KeyboardInterrupt:

# %%
placer

# %%
from keras import models, layers

# %%
x = placer.iloc['MODULENO','NUMCOMP','NUMBLOCKS','NUMERRORS']
y = placer.iloc[validation.iloc['F_data']]

# %%
model = models.Sequential()
model.add(layers.Dense(4, activation = 'relu',input_shape = (4,)))
model.add(layers.Dense(16,activation='relu'))
model.add(layers.Dense(8,activation='relu'))
model.add(layers.Dense(2,activation='relu'))
model.compile(optimizer='rmsprop' ,loss='categorical_crossentropy', metrics = ['accuracy'])

# %%
model.fit(x,y,epochs=5,batch_size=150)
